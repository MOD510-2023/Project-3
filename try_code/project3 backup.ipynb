# %% [markdown]
# # Project 3

# %% [markdown]
# ## Stirred

# %% [markdown]
# ## Group 1 9:
#
# - Mussa Banjai
# - Tapas Dev
# - Jason Kapka
# - Taz Ahmed

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Abstract

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import numba as nb
import matplotlib.pyplot as plt
import math as m
import scipy as sp
from scipy import optimize
import pandas as pd

# %% [markdown]
# ## ODE Solver class

# %%
class ODE_Solver:
    def __init__(
                self,
                #t,
                dt,
                n,
                #y,
                tau = 2,
                t0 = 0,
                tf = 1,
                protocol = 0,
                ):
        
        self.dt = dt
        self.n = n
        #self.y = y
        self.tau = tau
        self.t0 = t0
        self.tf = tf
        self.t = [] #np.arange(t0, tf, dt)#t
        self.c0 = np.zeros(n) # [0] * n
        self.c0[0] = 1
        self.protocol = protocol
        self.methods = ['euler','rk2','rk4']

    def f(self, c, t):
        cinj=self.c_inj()
        rhs=[]
        for i in range(self.n):
            if i==0:
                rhs.append(cinj-c[0])
            else:
                rhs.append(c[i-1] - c[i])
        return np.array(rhs) * self.n/self.tau


    def rk2(self, y, t):
        k1=self.dt*self.f(y, t)
        k2=self.dt*self.f(y+k1/2,t+self.dt/2)
        return k2

    def rk4(self, y, t):
        k1=self.dt*self.f(y, t)
        k2=self.dt*self.f(y+k1/2,t+self.dt/2)
        k3=self.dt*self.f(y+k2/2,t+self.dt/2)
        k4=self.dt*self.f(y+k3,t+self.dt)
        return (k1+2*k2+2*k3+k4)/6
    
    def solver(self, method):
        c=[]
        t=[]
        c.append(self.c0)
        t.append(self.t0)
        self.t=self.t0
        while(self.t<=self.tf):
            self.t=self.t+self.dt
            if method == 'euler':
                step=self.dt*self.f(c[-1], self.t)
            elif method == 'rk2':
                step=self.rk2(c[-1], self.t)
            elif method == 'rk4':
                step= self.rk4(c[-1], self.t)
            c.append(c[-1]+step)
            t.append(self.t)
        #print(np.array(t))
        #print(c)
        return np.array(t), np.array(c)
    
    def analytical(self, t):
        if self.n==1:
            return np.exp(-(t/self.tau))
        if self.n==2:
            return ((2*t)/self.tau) * np.exp(-(2*t/self.tau))
        if self.n == 3:
            return ((9*(t**2))/(2*self.tau**2)) * np.exp(-(3*t/self.tau))
    
    def c_inj(self):
        ti=[0,1.,1.,2.,2.]
        ci=[0,0,0,0,0]
        match self.protocol:
            case 1:
                ti=[0,1.,1.,2.,2.]
                ci=[1,1,0,0,0]
            case 2:
                ti=[0,1.,2.,2.]
                ci=[1,1,1,0]
            case 3:
                ti=[0,1.,2.,3.,3.]
                ci=[1,1,1,1,0]
            case 4:
                ti=[0,1.,1.,2.]
                ci=[0,1,0,0]
            case 5:
                ti=[0,2.,2.,3.]
                ci=[0,1,0,0]
            case 6:
                ti=[0,1.,1.,2.,2.,3.,3.,4.]
                ci=[0.7,0.7,0,0,1,1,0,0]
            case 0:
                ti=[0,1.,1.,2.,2.]
                ci=[0,0,0,0,0]
        return np.interp(self.t,ti,ci)
    
    def simulate(self):
        for method in self.methods:
            tn, cn = self.solver(method)
            plt.plot(tn,cn[:,-1],'*',label=method)
        plt.plot(tn,self.analytical(tn),label='analytical')
        plt.grid()
        plt.legend()

# %%
test = ODE_Solver(0.5, 1,tf=30, tau=7)
test.simulate()

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 1: Write your own ODE solver

# %% [markdown]
# ### Part 1

# %%
def f(c,t,tau=2, protocol = 0):
    n=len(c)
    cinj= c_inj(t,protocol)
    rhs=[]
    for i in range(n):
        if i==0:
            rhs.append(cinj-c[0])
        else:
            rhs.append(c[i-1] - c[i])
    # convert into numpy array
    return np.array(rhs) * n/tau
    # return -1/tau*c

def analytical(t,*,c0=[1,0,0],tau=2, n=1):
    if n==1:
        return np.exp(-(t/tau))
    if n==2:
        return ((2*t)/tau) * np.exp(-(2*t/tau))
    if n == 3:
        return ((9*(t**2))/(2*tau**2)) * np.exp(-(3*t/tau))

def f2(y,t,omega):
    Y0,Y1=y
    return np.array([Y1,-omega*omega*Y0])

# %%
def rk2(f,y,t,dt,*args,**kwargs):
    k1=dt*f(y,t,*args,**kwargs)
    k2=dt*f(y+k1/2,t+dt/2,*args,**kwargs)
    return k2

def rk4(f,y,t,dt,*args,**kwargs):
    k1=dt*f(y,t,*args,**kwargs)
    k2=dt*f(y+k1/2,t+dt/2,*args,**kwargs)
    k3=dt*f(y+k2/2,t+dt/2,*args,**kwargs)
    k4=dt*f(y+k3,t+dt,*args,**kwargs)
    return (k1+2*k2+2*k3+k4)/6


def ode_solver(f,c0,t0,tf,dt,method,*args,**kwargs):
    c=[]
    t=[]
    c.append(c0)
    t.append(t0)
    ti=t0
    while(ti<=tf):
        ti=ti+dt
        if method == 'euler':
            step=dt*f(c[-1],ti,*args,**kwargs)
        elif method == 'rk2':
            step=rk2(f,c[-1],ti,dt,*args,**kwargs)
        elif method == 'rk4':
            step= rk4(f,c[-1],ti,dt,*args,**kwargs)
        c.append(c[-1]+step)
        t.append(ti)
    return np.array(t),np.array(c)

# %% [markdown]
# ### Part 2

# %%
methods=['euler','rk2','rk4']
tf=30
t=np.linspace(0,tf,1000)
tau=7
for method in methods:
    tn,cn=ode_solver(f,c0=[1],t0=0,tf=30,dt=.5,method=method,tau=tau)
    plt.plot(tn,cn[:,-1],'*',label=method)
plt.plot(t,analytical(t,tau=tau, n=1),label='analytical')
plt.grid()
plt.legend()

# %%
methods=['euler','rk2','rk4']
tf=30
t=np.linspace(0,tf,1000)
tau=7
Stirred01 = ODE_Solver()
for method in methods:
    tn,cn=ode_solver(f,c0=[1],t0=0,tf=30,dt=.5,method=method,tau=tau)
    plt.plot(tn,cn[:,-1],'*',label=method)
plt.plot(t,analytical(t,tau=tau, n=1),label='analytical')
plt.grid()
plt.legend()

# %%
for method in methods:
    tn,cn=ode_solver(f,c0=[1,0],t0=0,tf=30,dt=.5,method=method,tau=tau)
    plt.plot(tn,cn[:,-1],'*',label=method)
plt.plot(t,analytical(t,tau=tau, n=2),label='analytical')
plt.grid()
plt.legend()

# %%
for method in methods:
    tn,cn=ode_solver(f,c0=[1,0,0],t0=0,tf=30,dt=.5,method=method,tau=tau)
    plt.plot(tn,cn[:, -1],'*',label=method)
plt.plot(t,analytical(t,tau=tau, n=3),label='analytical')
plt.grid()
plt.legend()

# %% [markdown]
# ### Part 3

# %% [markdown]
# #### 1

# %%
methods=['euler','rk2','rk4']
tf=1
dt = 0.1
t= np.arange(0, tf+dt, dt)
tau=2
for method in methods:
    tn,cn=ode_solver(f,c0=[1,0,0],t0=0,tf=1,dt=dt,method=method,tau=tau)
    plt.plot(tn,cn[:,-1],label=method)
#plt.plot(t,analytical(t,tau=tau, n=3),label='analytical')
plt.grid()
plt.legend()

# Cant be the exact

# %% [markdown]
# #### 2

# %% [markdown]
# <!---->

# %% [markdown]
# ## Exercise 2: Fit CSTR model to CFD model: Healthy aorta

# %% [markdown]
# ### Part 1

# %% [markdown]
# Data

# %%
healthy_rect_1s = pd.read_csv("data/Healthy_rect_1s.csv", delimiter=",")
hconcentration = healthy_rect_1s["Concentration"]
htime = healthy_rect_1s["Time"]
healthy_rect_1s
# Out:
#      Time  Concentration
# 0    0.00   0.000000e+00
# 1    0.02   0.000000e+00
# 2    0.04   0.000000e+00
# 3    0.06   0.000000e+00
# 4    0.08   0.000000e+00
# ..    ...            ...
# 246  4.92   8.620000e-06
# 247  4.94   4.980000e-06
# 248  4.96   2.020000e-06
# 249  4.98   2.510000e-08
# 250  5.00   1.190000e-06
#
# [251 rows x 2 columns]

# %% [markdown]
# Calculation

# %%
Minj = 83.33 # grams
Q =  np.trapz(hconcentration, x=htime)
q = Minj/Q

"""
The solution is in g/sec. Needs to convert to L/min
1 g/s = 0.060 L/min
"""
q = q*0.06
q
# Out:
# 5.005803448030458

# %% [markdown]
# ### Part 2

# %%
"""
ti
ci: c injection
qi: q injection
"""

def c_inj(t, protocol = 0):
    ti=[0,1.,1.,2.,2.]
    ci=[0,0,0,0,0]
    match protocol:
        case 1:
            ti=[0,1.,1.,2.,2.]
            ci=[1,1,0,0,0]
        case 2:
            ti=[0,1.,2.,2.]
            ci=[1,1,1,0]
        case 3:
            ti=[0,1.,2.,3.,3.]
            ci=[1,1,1,1,0]
        case 4:
            ti=[0,1.,1.,2.]
            ci=[0,1,0,0]
        case 5:
            ti=[0,2.,2.,3.]
            ci=[0,1,0,0]
        case 6:
            ti=[0,1.,1.,2.,2.,3.,3.,4.]
            ci=[0.7,0.7,0,0,1,1,0,0]
        case default:
            ti=[0,1.,1.,2.,2.]
            ci=[0,0,0,0,0]
    return np.interp(t,ti,ci)

# %%
x = np.arange(0, 5, 0.001)

plt.step(x, c_inj(x, 1))
plt.show()

# %%
c_inj(0, 1)
# Out:
# 1.0

# %%
x = np.arange(0, 5, 0.001)

plt.step(x, c_inj(x, 1))
plt.show()

# %%
def f_(c,t,tau=2):
    n=len(c)
    cinj=c_inj(t)
    print()
    rhs=[]
    for i in range(n):
        if i==0:
            rhs.append(cinj[0]-c[0])
        else:
            rhs.append(c[i-1] - c[i])
    # convert into numpy array
    return np.array(rhs) * n/tau
    # return -1/tau*c

# %% [markdown]
# ### Part 3

# %%
plt.plot(htime, hconcentration)
plt.step(htime, c_inj(htime, 1))

# %%
methods=['euler','rk2','rk4']
tf=1
dt = 0.1
t= np.arange(0, tf+dt, dt)#np.linspace(0,tf,1000)
tau=2
for method in methods:
    tn,cn=ode_solver(f,c0=[1,0,0],t0=0,tf=1,dt=dt,method=method,tau=tau)
    plt.plot(tn,cn[:,-1],'*',label=method)
plt.plot(t,analytical(t,tau=tau, n=3),label='analytical')
plt.grid()
plt.legend()

# %% [markdown]
# ### Part 4

# %% [markdown]
# ## Exercise 3: Fit CSTR model to CFD model: Aorta with aneurysm

# %% [markdown]
# ### Part 1

# %% [markdown]
# ### Part 2

# %% [markdown]
# ### Part 3

# %% [markdown]
# ### Part 4

# %% [markdown]
# ## Exercise 4: Extend model

# %% [markdown]
# ### Part 1

# %% [markdown]
# ### Part 2

# %% [markdown]
# ### Part 3

# %% [markdown]
# ### Part 4

# %% [markdown]
# ## Reflections
#
# ### How did we work?
# Basically, we worked on project in the group room, alongside with the lab classes which helped us a lot to discuss about the problems as well as finding the solution. We worked together even if any of us find any solution then we discussed about this and then came to a proper solution which looked like a good way of learning for us. Before finalizing any problem's solution, we together ended up with a good solution and agreed upon that.
#
# Jason created some initial coding and worked on finding the solutions to the problem in theoretical matter. Taz and Tapas worked also on the theorectical matter proofs final Python code. Mussa wrote large sections of Python code and acted as Project Manager by compiling the individual contributions into a final product.
#
#
# ### What we did in the project?
# We evaluated the analtical, numerical and line-source solution with two different boundary conditions and also found out the error between them by visuallizing the graphs. Then we matched our well test data from the provided file.
#
# ### Our Learnings?
# We learnt the implementation of different numerical solvers for the radial deffusivity equation. We also learnt about PressureSolver Class. Besides, we also came across the learning of using two different boundary conditions. Although we did struggle in some stages but this project will help us in near future.future.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## References
#
# 1) Aksel Hiorth. Computational Engineering and Modeling, 2021
#    https://github.com/ahiorth/CompEngineering
